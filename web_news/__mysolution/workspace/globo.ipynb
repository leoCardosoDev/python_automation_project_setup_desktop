# %%
import requests
from bs4 import BeautifulSoup

class SiteNoticias:
    def __init__(self, site, header_tags, class_names):
        """
        site: Nome descritivo do site (por exemplo, 'globo', 'uol')
        header_tags: Lista de possíveis tags de cabeçalho que encapsulam os títulos (ex: ['h2', 'h3'])
        class_names: Lista de possíveis nomes de classes que identificam títulos de notícias
        """
        self.site = site
        self.header_tags = header_tags
        self.class_names = class_names
        self.news = []

    def update_news(self, url):
        browsers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
        page = requests.get(url, headers=browsers)
        if page.status_code != 200:
            raise Exception(f"Failed to load page from {url}")
        
        resposta = page.text
        soup = BeautifulSoup(resposta, 'html.parser')
        noticias = soup.find_all('a')

        # Coletar notícias com base em diferentes tags e classes
        news_dict = {}
        for noticia in noticias:
            for tag in self.header_tags:
                header = noticia.find(tag)
                if header and any(cls in header.get('class', []) for cls in self.class_names):
                    # Armazenar título com link
                    news_dict[header.text] = noticia.get('href')
        self.news = news_dict

# %%
# Uso da classe SiteNoticias
globo_site = SiteNoticias(
    site='globo',
    header_tags=['h2', 'h3'],
    class_names=['post__title', 'post-multicontent__link--title__text', 'md:font-bolder']
)

globo_url = 'https://www.globo.com/'
globo_site.update_news(globo_url)

# Exibir notícias coletadas
for title, link in globo_site.news.items():
    print(f"Title: {title}\nLink: {link}\n")
# Out:
# Title: Justiça espanhola altera sentença por estupro e absolve Daniel Alves
# Link: https://g1.globo.com/mundo/noticia/2025/03/28/daniel-alves-e-absolvido-pela-justica-da-espanha.ghtml
#
# Title: Advogada de jovem diz que vai recorrer: 'Muito decepcionada e triste'
# Link: https://ge.globo.com/futebol/futebol-internacional/noticia/2025/03/28/caso-daniel-alves-advogada-de-jovem-diz-que-vai-recorrer-contra-revogacao-de-sentenca-e-absolvicao.ghtml
#
# Title: De 'lamentável' a 'temos que respeitar': imprensa reage
# Link: https://ge.globo.com/futebol/futebol-internacional/noticia/2025/03/28/totalmente-lamentavel-imprensa-internacional-reage-a-absolvicao-de-daniel-alves.ghtml
#
# Title: Organizações feministas e famosas se manifestam
# Link: https://revistamarieclaire.globo.com/noticias/noticia/2025/03/organizacoes-feministas-e-famosas-repudiam-anulacao-de-sentenca-de-daniel-alves.ghtml
#
# Title: Mc Kako fez sua estreia no 1º dia do Lolla; veja o festival
# Link: https://globoplay.globo.com/lollapalooza-brasil-sinal-gratuito/ao-vivo/10464011/?origemld=1020&utm_source=gcom&utm_medium=home&utm_campaign=gcom-edit&utm_term=LollaSinalGratuitoAoVivo
#
# Title: Assinante Globoplay vê todos os shows  em 4K
# Link: https://globoplay.globo.com/lollapalooza-brasil-multishow-4-k/ao-vivo/11529660/?origemld=1020&utm_source=gcom&utm_medium=home&utm_campaign=gcom-edit&utm_term=Lolla4KAoVivo
#
# Title: Público se protege da chuva no Lolla 2025; SIGA
# Link: https://g1.globo.com/pop-arte/musica/lollapalooza/2025/ao-vivo/lollapalooza-2025-ao-vivo-transmissao-de-shows-programacao-videos-fotos-e-cobertura-em-tempo-real.ghtml
#
# Title: Olivia Rodrigo fecha o dia hoje; veja hora dos shows
# Link: https://gshow.globo.com/festivais/lollapalooza/2025/noticia/lollapalooza-2025-olivia-rodrigo-e-rufus-du-sol-sao-os-headliners-do-primeiro-dia-de-festival.ghtml
#
# Title:  Arranha-céu desaba na Tailândia após terremoto; vídeo
#
# Title: Mãe acordar de cochilo e se depara com avó coberta com maquiagem roxa
# Link: https://vogue.globo.com/atualidades/noticia/2025/03/mae-viraliza-ao-acordar-de-cochilo-da-tarde-e-se-deparar-com-avo-coberta-com-maquiagem-roxa.ghtml
#
# Title: Clarice pede que Beatriz desista de Beto; veja detalhes da trama
# Link: https://gshow.globo.com/novelas/garota-do-momento/vem-por-ai/noticia/em-garota-do-momento-clarice-pede-que-beatriz-desista-de-beto.ghtml
#
# Title: Violeta e Osmar fecham negócio com Marco, mas são traídos
# Link: https://gshow.globo.com/novelas/volta-por-cima/vem-por-ai/noticia/volta-por-cima-violeta-e-osmar-fecham-negocio-com-marco-mas-sao-traidos.ghtml
#
# Title: Raquel leva golpe da filha; veja um resumo da primeira semana
# Link: https://gshow.globo.com/novelas/vale-tudo/noticia/gshow-em-vale-tudo-raquel-leva-golpe-da-filha.ghtml
#
# Title: Maiara vai se mudar para apê de R$ 10 milhões nas próximas semanas
# Link: https://gshow.globo.com/cultura-pop/famosos/noticia/maiara-vai-se-mudar-para-ape-de-r-10-milhoes-nas-proximas-semanas-imovel-tera-quarto-para-maraisa.ghtml
#
# Title: Casal diz como apimentou relação no swing: 'Fantasia era vê-la com outro'
# Link: https://gq.globo.com/sexo/noticia/2025/03/minha-fantasia-era-ve-la-com-outro-homem-casal-de-60-anos-conta-como-praticar-swing-apimentou-a-relacao.ghtml
#
# Title: Luana Piovani dá cantada em homem no aeroporto, envia bilhete e se frustra
# Link: https://revistamarieclaire.globo.com/celebridades/noticia/2025/03/luana-piovani-da-cantada-em-homem-no-aeroporto-manda-bilhete-e-se-frusta-ao-descobrir-que-ele-e-gay.ghtml
#
# Title: Agatha Moreira e Rodrigo Simas trocam beijos calientes no mar
# Link: https://gshow.globo.com/cultura-pop/famosos/noticia/treino-em-familia-irmaos-simas-jogam-futevolei-acompanhados-de-agatha-moreira-e-mariana-uhlmann.ghtml
#
# Title: Mulheres têm orgasmo na penetração? É problema não conseguir chegar lá?
# Link: https://revistamarieclaire.globo.com/sexo/noticia/2025/03/como-fazer-mulher-gozar-penetracao-sexo.ghtml
#
# Title: CartolaCast: temporada 2025 chega com pontuações novas e reserva de luxo
# Link: https://interativos.ge.globo.com/podcasts/programa/cartolacast/episodio/cartolacast-233-temporada-2025-chega-com-pontuacoes-novas-e-reserva-de-luxo/
#
# Title: Reginaldo Faria fala da expectativa para 'Vale tudo' e lembra situação inusitada em 'Dancin' Days'
# Link: https://oglobo.globo.com/play/entrevistas/noticia/2025/03/27/no-segundo-episodio-do-videocast-novelao-reginaldo-faria-fala-da-expectativa-para-vale-tudo-e-lembra-situacao-inusitada-em-dancin-days.ghtml
#
# Title: Encontre os melhores podcasts da Globo em um só lugar; aperte o play e divirta-se
# Link: https://www.globo.com/podcasts/

# %%
# Uso da classe SiteNoticias
r7_site = SiteNoticias(
    site='r7',
    header_tags=['h2', 'h3', 'h4', 'h5', 'h6'],
    class_names=[
        'r7-flex-title-h4__link',
        'r7-flex-title-h5__link',
        'r7-flex-title-h6__link',
        ]
)

r7_url = 'https://www.r7.com/'
r7_site.update_news(r7_url)

# Exibir notícias coletadas
for title, link in r7_site.news.items():
    print(f"Title: {title}\nLink: {link}\n")
